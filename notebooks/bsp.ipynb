# %% [markdown]
# Bike Sharing Prediction  ___ Explatory Data Analysis
# cnt(Target variable)

# %%
# Automatically reload updated modules before executing code
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.util import (load_and_explore_data,plot_eda_visualizations,
                      plot_distribution_plots,plot_scatter_plots)


from src.preprocessing import (
    clean_dataframe
)
from src.feature_engineering import (
    add_date_features,
    add_weather_features,
    add_cyclical_features,
    add_temperature_bins,
    create_engineered_features
)

# %% [markdown]
# Load and Explore, visualization

# %%
df= load_and_explore_data()

# %%
plot_eda_visualizations(df)
plot_scatter_plots(df)
plot_distribution_plots(df)

# %% [markdown]
# Preprocessing

# %%
# df= clean_dataframe(df)

# Test individual functions to inspect outputs easily
df_step1 = add_date_features(df)
df_step2 = add_weather_features(df_step1)
df_step3 = add_cyclical_features(df_step2)

df_step3

# df_step4 = add_temperature_bins(df_step3)

# %% [markdown]
# Feature Engineering

# %%
df= clean_dataframe(df)
df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning utilities
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Regression algorithms
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# Model evaluation metrics
from sklearn.metrics import (
mean_squared_error,
mean_absolute_error,
r2_score
)

# Statistical analysis
from scipy import stats
print("All libraries imported successfully!")

# %% [markdown]
# Data Exploration

# %%
df= pd.read_csv('../data/day.csv')
df.head()
df.tail()
row,col= df.shape
print(f"row: {row}, col: {col}")

# %% [markdown]
# 2. Data Preprocessing

# %%
numerical_col= df.select_dtypes(include=['number']).columns.tolist()
categorical_col= df.select_dtypes(include=['str']).columns.tolist()

print(f"numerical columns :{(numerical_col)}")
print(f"categorical columns :{(categorical_col)}")

print(f"missed values : {df.isnull().sum().sum()}")
# df.describe()
print(f"duplicate records: {df.duplicated().sum()}")
